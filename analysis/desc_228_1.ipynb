# %%
from main_simple_lib import *
code = """
def execute_command(image, my_fig, time_wait_between_lines, syntax):
    image_patch = ImagePatch(image)
    plot_patches = image_patch.find("plot")
    rightmost_tick = None
    for plot in plot_patches:
        x_axis_patches = plot.find("x-axis")
        for x_axis in x_axis_patches:
            tick_patches = x_axis.find("tick")
            for tick in tick_patches:
                if tick.horizontal_center > plot.horizontal_center:
                    label = tick.simple_query("What is the label?")
                    if rightmost_tick is None or tick.horizontal_center > rightmost_tick.horizontal_center:
                        rightmost_tick = tick
                        rightmost_label = label
    return rightmost_label
"""

code_for_syntax = code.replace("(image, my_fig, time_wait_between_lines, syntax)", "(image)")
syntax_1 = Syntax(code_for_syntax, "python", theme="monokai", line_numbers=True, start_line=0)
code = ast.unparse(ast.parse(code))
code_for_syntax_2 = code.replace("(image, my_fig, time_wait_between_lines, syntax)", "(image)")
syntax_2 = Syntax(code_for_syntax_2, "python", theme="monokai", line_numbers=True, start_line=0)

code = (code, syntax_2)

im = load_image("images/228.jpg")
execute_code(code, im, show_intermediate_steps=True)
# Out:
# 2025-04-26 09:31:57.125802: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-26 09:32:00.294239: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-26 09:32:13.481014: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /sw/pkgs/arc/cuda/12.1.1/lib64
# 2025-04-26 09:32:13.481124: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /sw/pkgs/arc/cuda/12.1.1/lib64
# 2025-04-26 09:32:13.481133: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Using cache found in /home/jhsansom/.cache/torch/hub/intel-isl_MiDaS_master
# Using cache found in /home/jhsansom/.cache/torch/hub/intel-isl_MiDaS_master
# VISION BACKBONE USE GRADIENT CHECKPOINTING:  False
# LANGUAGE BACKBONE USE GRADIENT CHECKPOINTING:  False
# EARLY FUSION ON, USING MHA-B
# EARLY FUSION ON, USING MHA-B
# EARLY FUSION ON, USING MHA-B
# EARLY FUSION ON, USING MHA-B
# EARLY FUSION ON, USING MHA-B
# EARLY FUSION ON, USING MHA-B
# EARLY FUSION ON, USING MHA-B
# EARLY FUSION ON, USING MHA-B
# <style>.output_wrapper, .output {height:auto !important; max-height:1000000px;}</style>
# Output()
# ───────────────────────────────────────────────────── Line 1 ──────────────────────────────────────────────────────
# image_patch =
# INSIDE FORWARD
# model_name: glip
# arg types: [<class 'torch.Tensor'>, <class 'str'>]
# queues: (None, None)
# kwargs: {}
# consumers: {'blip': <function make_fn.<locals>._function at 0x147ff9f756c0>, 'codex': <function
# make_fn.<locals>._function at 0x147ff9f75630>, 'depth': <function make_fn.<locals>._function at 0x147ff87ef2e0>,
# 'glip': <function make_fn.<locals>._function at 0x147c7f8c1cf0>, 'gpt3_qa': <function make_fn.<locals>._function at
# 0x147c7f8c1e10>, 'gpt3_general': <function make_fn.<locals>._function at 0x147c7f8c1fc0>, 'qwen_vl': <function
# make_fn.<locals>._function at 0x147c72cd1b40>, 'xvlm': <function make_fn.<locals>._function at 0x147c72cd1bd0>}
# consumers.keys(): dict_keys(['blip', 'codex', 'depth', 'glip', 'gpt3_qa', 'gpt3_general', 'qwen_vl', 'xvlm'])
# queues_in: None
# config.multiprocessing: False
# ───────────────────────────────────────────────────── Line 2 ──────────────────────────────────────────────────────
# plot_patches[0] =
# plot_patches[1] =
# ───────────────────────────────────────────────────── Line 3 ──────────────────────────────────────────────────────
# rightmost_tick = None
# ───────────────────────────────────────────────────── Line 4 ──────────────────────────────────────────────────────
# plot =
# INSIDE FORWARD
# model_name: glip
# arg types: [<class 'torch.Tensor'>, <class 'str'>]
# queues: (None, None)
# kwargs: {}
# consumers: {'blip': <function make_fn.<locals>._function at 0x147ff9f756c0>, 'codex': <function
# make_fn.<locals>._function at 0x147ff9f75630>, 'depth': <function make_fn.<locals>._function at 0x147ff87ef2e0>,
# 'glip': <function make_fn.<locals>._function at 0x147c7f8c1cf0>, 'gpt3_qa': <function make_fn.<locals>._function at
# 0x147c7f8c1e10>, 'gpt3_general': <function make_fn.<locals>._function at 0x147c7f8c1fc0>, 'qwen_vl': <function
# make_fn.<locals>._function at 0x147c72cd1b40>, 'xvlm': <function make_fn.<locals>._function at 0x147c72cd1bd0>}
# consumers.keys(): dict_keys(['blip', 'codex', 'depth', 'glip', 'gpt3_qa', 'gpt3_general', 'qwen_vl', 'xvlm'])
# queues_in: None
# config.multiprocessing: False
# ───────────────────────────────────────────────────── Line 5 ──────────────────────────────────────────────────────
# x_axis_patches[0] =
# x_axis_patches[1] =
# ───────────────────────────────────────────────────── Line 6 ──────────────────────────────────────────────────────
# x_axis =
# INSIDE FORWARD
# model_name: glip
# arg types: [<class 'torch.Tensor'>, <class 'str'>]
# queues: (None, None)
# kwargs: {}
# consumers: {'blip': <function make_fn.<locals>._function at 0x147ff9f756c0>, 'codex': <function
# make_fn.<locals>._function at 0x147ff9f75630>, 'depth': <function make_fn.<locals>._function at 0x147ff87ef2e0>,
# 'glip': <function make_fn.<locals>._function at 0x147c7f8c1cf0>, 'gpt3_qa': <function make_fn.<locals>._function at
# 0x147c7f8c1e10>, 'gpt3_general': <function make_fn.<locals>._function at 0x147c7f8c1fc0>, 'qwen_vl': <function
# make_fn.<locals>._function at 0x147c72cd1b40>, 'xvlm': <function make_fn.<locals>._function at 0x147c72cd1bd0>}
# consumers.keys(): dict_keys(['blip', 'codex', 'depth', 'glip', 'gpt3_qa', 'gpt3_general', 'qwen_vl', 'xvlm'])
# queues_in: None
# config.multiprocessing: False
# ───────────────────────────────────────────────────── Line 7 ──────────────────────────────────────────────────────
# tick_patches[0] =
# tick_patches[1] =
# ───────────────────────────────────────────────────── Line 8 ──────────────────────────────────────────────────────
# tick =
# ───────────────────────────────────────────────────── Line 9 ──────────────────────────────────────────────────────
# tick.horizontal_center = 513.5
# plot.horizontal_center = 510.0
# tick.horizontal_center > plot.horizontal_center = True
# INSIDE FORWARD
# model_name: qwen_vl
# arg types: [<class 'torch.Tensor'>, <class 'str'>]
# queues: (None, None)
# kwargs: {'task': 'qa'}
# consumers: {'blip': <function make_fn.<locals>._function at 0x147ff9f756c0>, 'codex': <function
# make_fn.<locals>._function at 0x147ff9f75630>, 'depth': <function make_fn.<locals>._function at 0x147ff87ef2e0>,
# 'glip': <function make_fn.<locals>._function at 0x147c7f8c1cf0>, 'gpt3_qa': <function make_fn.<locals>._function at
# 0x147c7f8c1e10>, 'gpt3_general': <function make_fn.<locals>._function at 0x147c7f8c1fc0>, 'qwen_vl': <function
# make_fn.<locals>._function at 0x147c72cd1b40>, 'xvlm': <function make_fn.<locals>._function at 0x147c72cd1bd0>}
# consumers.keys(): dict_keys(['blip', 'codex', 'depth', 'glip', 'gpt3_qa', 'gpt3_general', 'qwen_vl', 'xvlm'])
# queues_in: None
# config.multiprocessing: False
# ───────────────────────────────────────────────────── Line 10 ─────────────────────────────────────────────────────
# label = Ground Truth Baseline
# ───────────────────────────────────────────────────── Line 11 ─────────────────────────────────────────────────────
# rightmost_tick is None or tick.horizontal_center = True
# Encountered error 'NoneType' object has no attribute 'horizontal_center' when trying to run with visualizations.
# Trying from scratch.
# INSIDE FORWARD
# model_name: glip
# arg types: [<class 'torch.Tensor'>, <class 'str'>]
# queues: (None, None)
# kwargs: {}
# consumers: {'blip': <function make_fn.<locals>._function at 0x147ff9f756c0>, 'codex': <function
# make_fn.<locals>._function at 0x147ff9f75630>, 'depth': <function make_fn.<locals>._function at 0x147ff87ef2e0>,
# 'glip': <function make_fn.<locals>._function at 0x147c7f8c1cf0>, 'gpt3_qa': <function make_fn.<locals>._function at
# 0x147c7f8c1e10>, 'gpt3_general': <function make_fn.<locals>._function at 0x147c7f8c1fc0>, 'qwen_vl': <function
# make_fn.<locals>._function at 0x147c72cd1b40>, 'xvlm': <function make_fn.<locals>._function at 0x147c72cd1bd0>}
# consumers.keys(): dict_keys(['blip', 'codex', 'depth', 'glip', 'gpt3_qa', 'gpt3_general', 'qwen_vl', 'xvlm'])
# queues_in: None
# config.multiprocessing: False
# INSIDE FORWARD
# model_name: glip
# arg types: [<class 'torch.Tensor'>, <class 'str'>]
# queues: (None, None)
# kwargs: {}
# consumers: {'blip': <function make_fn.<locals>._function at 0x147ff9f756c0>, 'codex': <function
# make_fn.<locals>._function at 0x147ff9f75630>, 'depth': <function make_fn.<locals>._function at 0x147ff87ef2e0>,
# 'glip': <function make_fn.<locals>._function at 0x147c7f8c1cf0>, 'gpt3_qa': <function make_fn.<locals>._function at
# 0x147c7f8c1e10>, 'gpt3_general': <function make_fn.<locals>._function at 0x147c7f8c1fc0>, 'qwen_vl': <function
# make_fn.<locals>._function at 0x147c72cd1b40>, 'xvlm': <function make_fn.<locals>._function at 0x147c72cd1bd0>}
# consumers.keys(): dict_keys(['blip', 'codex', 'depth', 'glip', 'gpt3_qa', 'gpt3_general', 'qwen_vl', 'xvlm'])
# queues_in: None
# config.multiprocessing: False
# INSIDE FORWARD
# model_name: glip
# arg types: [<class 'torch.Tensor'>, <class 'str'>]
# queues: (None, None)
# kwargs: {}
# consumers: {'blip': <function make_fn.<locals>._function at 0x147ff9f756c0>, 'codex': <function
# make_fn.<locals>._function at 0x147ff9f75630>, 'depth': <function make_fn.<locals>._function at 0x147ff87ef2e0>,
# 'glip': <function make_fn.<locals>._function at 0x147c7f8c1cf0>, 'gpt3_qa': <function make_fn.<locals>._function at
# 0x147c7f8c1e10>, 'gpt3_general': <function make_fn.<locals>._function at 0x147c7f8c1fc0>, 'qwen_vl': <function
# make_fn.<locals>._function at 0x147c72cd1b40>, 'xvlm': <function make_fn.<locals>._function at 0x147c72cd1bd0>}
# consumers.keys(): dict_keys(['blip', 'codex', 'depth', 'glip', 'gpt3_qa', 'gpt3_general', 'qwen_vl', 'xvlm'])
# queues_in: None
# config.multiprocessing: False
# INSIDE FORWARD
# model_name: qwen_vl
# arg types: [<class 'torch.Tensor'>, <class 'str'>]
# queues: (None, None)
# kwargs: {'task': 'qa'}
# consumers: {'blip': <function make_fn.<locals>._function at 0x147ff9f756c0>, 'codex': <function
# make_fn.<locals>._function at 0x147ff9f75630>, 'depth': <function make_fn.<locals>._function at 0x147ff87ef2e0>,
# 'glip': <function make_fn.<locals>._function at 0x147c7f8c1cf0>, 'gpt3_qa': <function make_fn.<locals>._function at
# 0x147c7f8c1e10>, 'gpt3_general': <function make_fn.<locals>._function at 0x147c7f8c1fc0>, 'qwen_vl': <function
# make_fn.<locals>._function at 0x147c72cd1b40>, 'xvlm': <function make_fn.<locals>._function at 0x147c72cd1bd0>}
# consumers.keys(): dict_keys(['blip', 'codex', 'depth', 'glip', 'gpt3_qa', 'gpt3_general', 'qwen_vl', 'xvlm'])
# queues_in: None
# config.multiprocessing: False
# INSIDE FORWARD
# model_name: glip
# arg types: [<class 'torch.Tensor'>, <class 'str'>]
# queues: (None, None)
# kwargs: {}
# consumers: {'blip': <function make_fn.<locals>._function at 0x147ff9f756c0>, 'codex': <function
# make_fn.<locals>._function at 0x147ff9f75630>, 'depth': <function make_fn.<locals>._function at 0x147ff87ef2e0>,
# 'glip': <function make_fn.<locals>._function at 0x147c7f8c1cf0>, 'gpt3_qa': <function make_fn.<locals>._function at
# 0x147c7f8c1e10>, 'gpt3_general': <function make_fn.<locals>._function at 0x147c7f8c1fc0>, 'qwen_vl': <function
# make_fn.<locals>._function at 0x147c72cd1b40>, 'xvlm': <function make_fn.<locals>._function at 0x147c72cd1bd0>}
# consumers.keys(): dict_keys(['blip', 'codex', 'depth', 'glip', 'gpt3_qa', 'gpt3_general', 'qwen_vl', 'xvlm'])
# queues_in: None
# config.multiprocessing: False
# INSIDE FORWARD
# model_name: glip
# arg types: [<class 'torch.Tensor'>, <class 'str'>]
# queues: (None, None)
# kwargs: {}
# consumers: {'blip': <function make_fn.<locals>._function at 0x147ff9f756c0>, 'codex': <function
# make_fn.<locals>._function at 0x147ff9f75630>, 'depth': <function make_fn.<locals>._function at 0x147ff87ef2e0>,
# 'glip': <function make_fn.<locals>._function at 0x147c7f8c1cf0>, 'gpt3_qa': <function make_fn.<locals>._function at
# 0x147c7f8c1e10>, 'gpt3_general': <function make_fn.<locals>._function at 0x147c7f8c1fc0>, 'qwen_vl': <function
# make_fn.<locals>._function at 0x147c72cd1b40>, 'xvlm': <function make_fn.<locals>._function at 0x147c72cd1bd0>}
# consumers.keys(): dict_keys(['blip', 'codex', 'depth', 'glip', 'gpt3_qa', 'gpt3_general', 'qwen_vl', 'xvlm'])
# queues_in: None
# config.multiprocessing: False
# INSIDE FORWARD
# model_name: glip
# arg types: [<class 'torch.Tensor'>, <class 'str'>]
# queues: (None, None)
# kwargs: {}
# consumers: {'blip': <function make_fn.<locals>._function at 0x147ff9f756c0>, 'codex': <function
# make_fn.<locals>._function at 0x147ff9f75630>, 'depth': <function make_fn.<locals>._function at 0x147ff87ef2e0>,
# 'glip': <function make_fn.<locals>._function at 0x147c7f8c1cf0>, 'gpt3_qa': <function make_fn.<locals>._function at
# 0x147c7f8c1e10>, 'gpt3_general': <function make_fn.<locals>._function at 0x147c7f8c1fc0>, 'qwen_vl': <function
# make_fn.<locals>._function at 0x147c72cd1b40>, 'xvlm': <function make_fn.<locals>._function at 0x147c72cd1bd0>}
# consumers.keys(): dict_keys(['blip', 'codex', 'depth', 'glip', 'gpt3_qa', 'gpt3_general', 'qwen_vl', 'xvlm'])
# queues_in: None
# config.multiprocessing: False
# INSIDE FORWARD
# model_name: qwen_vl
# arg types: [<class 'torch.Tensor'>, <class 'str'>]
# queues: (None, None)
# kwargs: {'task': 'qa'}
# consumers: {'blip': <function make_fn.<locals>._function at 0x147ff9f756c0>, 'codex': <function
# make_fn.<locals>._function at 0x147ff9f75630>, 'depth': <function make_fn.<locals>._function at 0x147ff87ef2e0>,
# 'glip': <function make_fn.<locals>._function at 0x147c7f8c1cf0>, 'gpt3_qa': <function make_fn.<locals>._function at
# 0x147c7f8c1e10>, 'gpt3_general': <function make_fn.<locals>._function at 0x147c7f8c1fc0>, 'qwen_vl': <function
# make_fn.<locals>._function at 0x147c72cd1b40>, 'xvlm': <function make_fn.<locals>._function at 0x147c72cd1bd0>}
# consumers.keys(): dict_keys(['blip', 'codex', 'depth', 'glip', 'gpt3_qa', 'gpt3_general', 'qwen_vl', 'xvlm'])
# queues_in: None
# config.multiprocessing: False
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ────────────────────────────────────────────────── Final Result ───────────────────────────────────────────────────
# Result = Ground Truth Baseline
# 'Ground Truth Baseline'
